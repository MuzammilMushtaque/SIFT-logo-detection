# %%
import cv2
import numpy as np
import requests
from io import BytesIO
import json
import matplotlib.pyplot as plt
import random

# Input from user
input_file_name = input('Input File Name (e.g., Bio_Data.json or Rainforest_Data.json): ')
input_logo_file = input('Which Logo to detect (e.g., Bio_logo.png or rainforest_logo.png): ')

def download_image(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            image = np.asarray(bytearray(response.content), dtype=np.uint8)
            image = cv2.imdecode(image, cv2.IMREAD_COLOR)
            return image
        else:
            print("Failed to download image from URL:", url)
            return None
    except Exception as e:
        print("Error downloading image from URL:", url)
        print(e)
        return None

def detect_sift_keypoints(image):
    sift = cv2.SIFT_create()
    keypoints, descriptors = sift.detectAndCompute(image, None)
    return keypoints, descriptors

def match_keypoints(descriptors1, descriptors2):
    bf_matcher = cv2.BFMatcher()
    matches = bf_matcher.knnMatch(descriptors1, descriptors2, k=2)
    good_matches = []
    for m, n in matches:
        if m.distance < 0.40 * n.distance:  # Adjust the threshold as needed, 0.40 standard for vegan
            good_matches.append(m)
    return good_matches

def verify_keypoint_matches(image1, image2, keypoints1, keypoints2, matches):
    verified_matches = []
    for match in matches:
        kp1 = keypoints1[match.queryIdx]
        kp2 = keypoints2[match.trainIdx]
        
        x1, y1 = int(kp1.pt[0]), int(kp1.pt[1])
        x2, y2 = int(kp2.pt[0]), int(kp2.pt[1])
        roi1 = image1[max(y1-10, 0):y1+10, max(x1-10, 0):x1+10]
        roi2 = image2[max(y2-10, 0):y2+10, max(x2-10, 0):x2+10]

        contours1, _ = cv2.findContours(roi1, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        contours2, _ = cv2.findContours(roi2, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        area1 = cv2.contourArea(contours1[0]) if contours1 else 0
        area2 = cv2.contourArea(contours2[0]) if contours2 else 0

        if area1 > 0 and area2 > 0 and abs(area1 - area2) < 5:  # Ensure valid contours and adjust threshold as needed
            verified_matches.append(match)
    
    return verified_matches

def classify_product(images, logo_images):
    logo_count = []
    total_verified_matches = []
    for i in range(len(images)):
        logo_detected_count = 0
        product_image = images[i]
        logo_image = logo_images[i]
        
        keypoints_product, descriptors_product = detect_sift_keypoints(product_image)
        keypoints_logo, descriptors_logo = detect_sift_keypoints(logo_image)
        matches = match_keypoints(descriptors_product, descriptors_logo)
        verified_matches = verify_keypoint_matches(product_image, logo_image, keypoints_product, keypoints_logo, matches)
        
        total_verified_matches.append(len(verified_matches))

        if len(verified_matches) >= 1:
            logo_detected_count += 1
        logo_count.append(logo_detected_count)
        
    print('Total verified matches:', sum(total_verified_matches))
    print ('Total RGB color matches out of 3 :', sum(logo_count))
    if (sum(logo_count) >= 2) and (sum(total_verified_matches) >= threshold_matches):
        return (detecting_name, sum(logo_count), sum(total_verified_matches))
    else:
        return ('Non-'+detecting_name, sum(logo_count), sum(total_verified_matches))

def read_product_image(url):
    product_image = download_image(url)
    logo_image = cv2.imread(str(input_logo_file))
    return (product_image, logo_image)

def split_color_channels(product_image, logo_image):
    product_channels = cv2.split(product_image)
    logo_channels = cv2.split(logo_image)
    return (product_channels, logo_channels)

def main_function(data):
    for i, entry in enumerate(data):
        print('Processing URL number:', i+1)
        url = entry['Product_Image']
        print(url)
        global detecting_name
        global threshold_matches
        product_image, logo_image = read_product_image(url)
        if input_file_name == 'Bio_Data.json':
            column_name, detecting_name, threshold_matches = 'IsBio', 'Bio', 1
        elif input_file_name == 'Rainforest_Data.json':
            column_name, detecting_name, threshold_matches = 'IsRainforest', 'Rainforest', 30 
            
        if product_image is None or logo_image is None:
            print("Error: Unable to download or process image")
            continue

        product_channels, logo_channels = split_color_channels(product_image, logo_image)

        if product_channels is None or logo_channels is None:
            print("Error: Unable to split color channels")
            continue

        classification, color_match, verified_match_count = classify_product(product_channels, logo_channels)       
        print('Detected:', classification, '    Actual:', entry[column_name])
        entry['SIFT_ContourArea_detection'] = classification
        entry['SIFT_ContourArea_detection_colormatch'] = color_match
        entry['SIFT_ContourArea_detection_verifymatch'] = verified_match_count
        print('*' * 100)


# Read JSON file line by line and append each JSON object to combined_data list
with open(input_file_name, 'r', encoding='utf-8') as json_file:
    combined_data = json.load(json_file)

main_function(combined_data)

with open('Result_Detection.json', 'w') as json_file:
    json.dump(combined_data, json_file, indent=4)
# Out:
# Input File Name (e.g., Bio_Data.json or Rainforest_Data.json): Bio_Data.json
# Which Logo to detect (e.g., Bio_logo.png or rainforest_logo.png): Bio_logo.png
# Processing URL number: 1
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw51/produkte/1009614_51-2023_EhrmannGrandDessert-Vanille_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1700731629013/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 2
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2024/kw02/produkte/1002315_02-2024_BioLeinoel-FS_ON.png/_jcr_content/renditions/opt.1250w.png.res/1702543068979/opt.1250w.png
# Total verified matches: 11
# Total RGB color matches out of 3 : 2
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 3
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw28/produkte/1007264_28-2023_BraunerRohrzucker-fein_COMP.png/_jcr_content/renditions/opt.1250w.png.res/1687794296828/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 4
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw09/produkte/4554_09-2023_GUTBIOHVOLLMILCH-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1676477092254/opt.1250w.png
# Total verified matches: 14
# Total RGB color matches out of 3 : 2
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 5
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2024/kw12/produkte/1025916_11-2024_BioSchlagsahne-1_ON.png/_jcr_content/renditions/opt.1250w.png.res/1709223077150/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 6
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/backwaren/1007874_48-2021_BioKnusperKnaecke-3Saat_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1637933592705/opt.1250w.png
# Total verified matches: 12
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 7
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw24/produkte/3484_24-2023_Knusperriegel-02_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1684921698569/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 8
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw46/produkte/6525_46-2023_DEUTSCHEMARKENBUTTER250G-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1698229434608/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 9
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/kaffee/1029559_32-2023_BioFairstrade-FS_ON.png/_jcr_content/renditions/opt.1250w.png.res/1698163324624/opt.1250w.png
# Total verified matches: 33
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 10
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/fleisch/1015415_49-2022_RindRumpsteak-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1670941004667/opt.1250w.png
# Failed to download image from URL: https://www.aldi-nord.de/content/dam/aldi/germany/produkte/fleisch/1015415_49-2022_RindRumpsteak-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1670941004667/opt.1250w.png
# Error: Unable to download or process image
# Processing URL number: 11
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/wurst/7422_49-2022_GEFLUEGELAUFSCHNITT-Paprika_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1670400178655/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 12
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/alkoholfreie-getraenke/7232_42-2021_BIOORANGENSAFT1L-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1629205593656/opt.1250w.png
# Total verified matches: 15
# Total RGB color matches out of 3 : 2
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 13
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw01/produkte/2052_01-2023_MondaminSuesseGerichte-04_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1670509492150/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 14
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/kosmetik-pflege/3542_02-2022_AxeDuschgel400ml-IceChill_Comp2.png/_jcr_content/renditions/opt.1250w.png.res/1643809039522/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 15
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/vollsortiment/8180_15-2024_BioHuelsenfruechte-Berglinsen_ON.png/_jcr_content/renditions/opt.1250w.png.res/1710662554959/opt.1250w.png
# Total verified matches: 38
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 16
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2022/kw29/produkte/1014988_29-2022_BasmatiReis-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1656663890242/opt.1250w.png
# Failed to download image from URL: https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2022/kw29/produkte/1014988_29-2022_BasmatiReis-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1656663890242/opt.1250w.png
# Error: Unable to download or process image
# Processing URL number: 17
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2024/kw03/produkte/3890_03-2024_BioRindersteaks-FS-03_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1704287297884/opt.1250w.png
# Total verified matches: 9
# Total RGB color matches out of 3 : 2
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 18
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw07/produkte/1017013_07-2023_GintonicRumCola-02_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1674132003832/opt.1250w.png
# Failed to download image from URL: https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw07/produkte/1017013_07-2023_GintonicRumCola-02_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1674132003832/opt.1250w.png
# Error: Unable to download or process image
# Processing URL number: 19
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw01/produkte/6584_01-2023_VitalFitMehrkornbroetchen-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1670512811485/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 20
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw28/produkte/1012088_28-2023_SodastarZylinder-FS_ON.png/_jcr_content/renditions/opt.1250w.png.res/1686904010051/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 21
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2024/kw13/produkte/1011534_13-2024_FunkyAmericanVegan-FS03_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1709540750644/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 22
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/sommersortiment/8350_12-2023_COLOMBARDSAUVIGNONVIN-02_ON.png/_jcr_content/renditions/opt.1250w.png.res/1680257403103/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 23
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/muesli-cornflakes-cerealien/3445_38-2021_Haferpops-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1638284343428/opt.1250w.png
# Failed to download image from URL: https://www.aldi-nord.de/content/dam/aldi/germany/produkte/muesli-cornflakes-cerealien/3445_38-2021_Haferpops-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1638284343428/opt.1250w.png
# Error: Unable to download or process image
# Processing URL number: 24
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw09/produkte/4555_09-2023_BioHMilch-Fettarm_ON.png/_jcr_content/renditions/opt.1250w.png.res/1676477734887/opt.1250w.png
# Total verified matches: 26
# Total RGB color matches out of 3 : 2
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 25
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/vollsortiment/1025619_48-2023_BioHonig-02_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1701933131185/opt.1250w.png
# Total verified matches: 34
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 26
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2022/kw50/produkte/4698_50-2022_SchweinRindHacklfleichgemischt400g-01_ON1.png/_jcr_content/renditions/opt.1250w.png.res/1669287274045/opt.1250w.png
# Total verified matches: 39
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 27
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/antipasti-feinkost/6613_48-2022_Matjesfilets-03_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1669968943415/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 28
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/wein/1093_34-2021_BioWeissweinCuvee_ON.png/_jcr_content/renditions/opt.1250w.png.res/1625473478325/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 29
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw48/produkte/1022974_48-2023_TkBioLachsfiletMitHaut-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1699284339088/opt.1250w.png
# Total verified matches: 19
# Total RGB color matches out of 3 : 2
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 30
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw14/produkte/0783_14-2023_BioSuessrahmbutter-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1679498580168/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 31
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/milchprodukte/1473_46-2021_BIOKAESESTUECKE-Emmentaler_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1636123724674/opt.1250w.png
# Total verified matches: 57
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 32
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2020/kw46/produkte/6880_47-2020_Pizz-Ah_PizzaTonno_ON.png/_jcr_content/renditions/opt.1250w.png.res/1604486364395/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 33
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw19/produkte/1008667_19-2023_BioGewuerze-02_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1682003472669/opt.1250w.png
# Total verified matches: 1
# Total RGB color matches out of 3 : 1
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 34
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2022/kw20/produkte/1008998_20-2022_JMDEFrucht-schwarzwaelderKirsch_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1651652026765/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 35
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/konserven/1215_41-2021_ANANASINSCHEIBEN580ML-01_ON.png/_jcr_content/renditions/original.transform/1250w/img.1630332272890.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 36
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw52/produkte/1029579_01-2024_BioEspresso-Pack_ON.png/_jcr_content/renditions/opt.1250w.png.res/1702308844780/opt.1250w.png
# Total verified matches: 30
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 37
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2022/kw32/produkte/1626_32-2022_FrischkaeseNatur-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1658231954160/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 38
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/tiefgekuehltes/7274_44-2021_TKLaugenbrezenStangerl-Stangen_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1637237659684/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 39
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2022/kw51/produkte/1707_49-2022_NuernbergerRostbratwuerste-FS_ON2.png/_jcr_content/renditions/opt.1250w.png.res/1670340581423/opt.1250w.png
# Total verified matches: 4
# Total RGB color matches out of 3 : 2
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 40
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw21/produkte/5258_21-2023_SENSATIONMINI12X50ML-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1683045305123/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 41
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2024/kw02/produkte/1030056_02-2024_MYWAYBioMandelKokosnussdrink-02_ON_Com.png/_jcr_content/renditions/opt.1250w.png.res/1702547757025/opt.1250w.png
# Total verified matches: 19
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 42
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2022/kw20/produkte/1016069_20-2022_BABYPFLEGETCHER-03_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1650868616802/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 43
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/vollsortiment/2977_48-2023_BioKonfituere-02_ON_Com.png/_jcr_content/renditions/opt.1250w.png.res/1701933138098/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 44
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw08/produkte/1012196_06-2023_BioReibekaese150g-3_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1675695153075/opt.1250w.png
# Total verified matches: 1
# Total RGB color matches out of 3 : 1
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 45
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/backwaren/1010235_48-2021_Mehrkornbrot-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1638210955718/opt.1250w.png
# Failed to download image from URL: https://www.aldi-nord.de/content/dam/aldi/germany/produkte/backwaren/1010235_48-2021_Mehrkornbrot-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1638210955718/opt.1250w.png
# Error: Unable to download or process image
# Processing URL number: 46
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/vollsortiment/1025142_01-2024_NaturlandBioMilch-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1707297008470/opt.1250w.png
# Total verified matches: 13
# Total RGB color matches out of 3 : 2
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 47
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2021/kw02/produkte/1093_32-2020_LAMANCHASPANIENBIO075L-GutBio_ON.png/_jcr_content/renditions/opt.1250w.png.res/1608637886223/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 48
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/kosmetik-pflege/1002481_50-2021_WindelnXLGR6-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1636642785959/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 49
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw46/produkte/1021439_45-2023_FUGHackfleischgemischt-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1699431780958/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 50
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/wurst/1006670_40-2021_SCHINKENLYONER-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1627917661079/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 51
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/vollsortiment_2020/4125_26-2020_Fruchtcocktail_0000_COMP_ON.png/_jcr_content/renditions/opt.1250w.png.res/1591802107270/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 52
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw15/produkte/1021658_15-2023_MiniKabanossi250G-scharf_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1678872618038/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 53
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw09/produkte/1006162_09-2023_KnorrSaucen-04_ON_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1675353504132/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 54
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/vollsortiment/1000673_01-2024_BioHaferDrink1L-02_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1704445324393/opt.1250w.png
# Total verified matches: 30
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 55
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2022/kw30/produkte/8695_30-2022_HAMBURGER400G-FS-4x100g_ON1.png/_jcr_content/renditions/opt.1250w.png.res/1658501337438/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 56
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/wurst/1018544_24-2022_Gefluegelwuerstchen-FS_ON.png/_jcr_content/renditions/opt.1250w.png.res/1658818691903/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 57
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/alkoholfreie-getraenke/0354_21-2022_RiverCola-01_ON02.png/_jcr_content/renditions/opt.1250w.png.res/1651677868825/opt.1250w.png
# Failed to download image from URL: https://www.aldi-nord.de/content/dam/aldi/germany/produkte/alkoholfreie-getraenke/0354_21-2022_RiverCola-01_ON02.png/_jcr_content/renditions/opt.1250w.png.res/1651677868825/opt.1250w.png
# Error: Unable to download or process image
# Processing URL number: 58
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw36/produkte/6796_33-2023_Hafercookies-02_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1692372346018/opt.1250w.png
# Total verified matches: 4
# Total RGB color matches out of 3 : 2
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 59
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/fisch/6338_41-2020_BioGarnelen-Garnelen_ON.png/_jcr_content/renditions/opt.1250w.png.res/1626870216853/opt.1250w.png
# Total verified matches: 32
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 60
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2024/kw02/produkte/1027020_02-2024_NaturlandBioDinkelmehl-Vollkorn_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1702546204613/opt.1250w.png
# Total verified matches: 32
# Total RGB color matches out of 3 : 2
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 61
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2024/kw01/produkte/1007944_01-2024_Tomatensauce-Klassik_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1702901251405/opt.1250w.png
# Total verified matches: 29
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 62
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/milchprodukte/1002013_46-2021_BIOSCHLAGSAHNE30200G-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1630408046599/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 63
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw49/produkte/1021245_49-2023_MilkaGrosstafelDisplay-Nussini_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1699865470739/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 64
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/backzutaten-kochzutaten/3121_48-2020_Backpulver-BackFamily-EINZEL_ON.png/_jcr_content/renditions/opt.1250w.png.res/1608127269278/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 65
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/vollsortiment/1008778_02-2024_BioTofu-02_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1704460619802/opt.1250w.png
# Total verified matches: 5
# Total RGB color matches out of 3 : 1
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 66
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/suessigkeiten/4156_36-2021_FAIRTRADEBIOSCHOKO-Orange_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1626944726482/opt.1250w.png
# Total verified matches: 42
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 67
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2024/kw16/produkte/8180_15-2024_BioHuelsenfruechte-roteLinsenOekoTest_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1710844423739/opt.1250w.png
# Total verified matches: 52
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 68
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/vollsortiment/0300_35-2023_BioGartensaft-02_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1702389021261/opt.1250w.png
# Total verified matches: 24
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 69
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/milchprodukte/0882_46-2021_IrischerCheddarSortiment-Stueck_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1636121281820/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 70
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw03/produkte/7098_03-2023_BioKochschinkenKasseler-02_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1671701262958/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 71
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/kosmetik-pflege/1005072_50-2021_SATESSATampons-Super_COMP.png/_jcr_content/renditions/opt.1250w.png.res/1641559946017/opt.1250w.png
# Failed to download image from URL: https://www.aldi-nord.de/content/dam/aldi/germany/produkte/kosmetik-pflege/1005072_50-2021_SATESSATampons-Super_COMP.png/_jcr_content/renditions/opt.1250w.png.res/1641559946017/opt.1250w.png
# Error: Unable to download or process image
# Processing URL number: 72
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/fleisch/3574_33-2023_HaehnchenInnenfilet400g-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1690345544581/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 73
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw46/produkte/1019313_46-2023_PoppBrotaufstriche-Tunfisch_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1698050402636/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 74
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/suessigkeiten/9449_49-2019_DISNEYKINDERKEKS_0001_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1575644994696/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 75
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/muesli-cornflakes-cerealien/1717_38-2023_PremiumMuesli-Choc_COM.png/_jcr_content/renditions/opt.1250w.png.res/1698233301687/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 76
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/milchprodukte/4575_35-2021_BioFeta-FS_ON.png/_jcr_content/renditions/opt.1250w.png.res/1627050471382/opt.1250w.png
# Total verified matches: 26
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 77
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2024/kw13/produkte/1022481_13-2024_FrischkaeseNatur-02_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1709540614668/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 78
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw45/produkte/1028816_45-2023_FeinschmeckerSalami-03_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1697537668023/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 79
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw08/produkte/4674_08-2023_BIOAPFELDIREKTSAFTNATURTRB1L-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1675937347400/opt.1250w.png
# Total verified matches: 1
# Total RGB color matches out of 3 : 1
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 80
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw48/produkte/1238_48-2023_BioRotweincuvee-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1699460187399/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 81
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2021/kw01/produkte/1002316_01-2021_SK_BioChiaSamen_FS_0536_ON.png/_jcr_content/renditions/opt.1250w.png.res/1607428139847/opt.1250w.png
# Total verified matches: 11
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 82
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/wurst/6405_50-2022_HAUCHFEINEXCELLENCEQS125150G-Schinkenwurst_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1671184868049/opt.1250w.png
# Failed to download image from URL: https://www.aldi-nord.de/content/dam/aldi/germany/produkte/wurst/6405_50-2022_HAUCHFEINEXCELLENCEQS125150G-Schinkenwurst_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1671184868049/opt.1250w.png
# Error: Unable to download or process image
# Processing URL number: 83
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2024/kw02/produkte/1026192_02-2024_NaturlandBioJoghurt-02_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1702546173585/opt.1250w.png
# Total verified matches: 2
# Total RGB color matches out of 3 : 2
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 84
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/vollsortiment_2020/1006283_50-2020_Kraeuter-Oregano_ON.png/_jcr_content/renditions/opt.1250w.png.res/1605714214906/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 85
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw35/produkte/6468_35-2023_BioKaeseScheiben-03_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1691049723308/opt.1250w.png
# Total verified matches: 2
# Total RGB color matches out of 3 : 1
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 86
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2024/kw02/produkte/1003138_02-2024_NussSortiment-02_ON_Comp1.png/_jcr_content/renditions/opt.1250w.png.res/1703146952694/opt.1250w.png
# Total verified matches: 4
# Total RGB color matches out of 3 : 2
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 87
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2022/kw47/produkte/8595_47-2022_NUSSVARIATION-01_ON1.png/_jcr_content/renditions/opt.1250w.png.res/1668012005843/opt.1250w.png
# Failed to download image from URL: https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2022/kw47/produkte/8595_47-2022_NUSSVARIATION-01_ON1.png/_jcr_content/renditions/opt.1250w.png.res/1668012005843/opt.1250w.png
# Error: Unable to download or process image
# Processing URL number: 88
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw40/produkte/1016725_40-2023_Rebenbogen-02_ON.png/_jcr_content/renditions/opt.1250w.png.res/1694432681561/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 89
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw45/produkte/3926_45-2023_Nimm2-02_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1697532518817/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 90
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/vollsortiment/1519_01-2024_VeganeBioStreichcreme-06_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1704460612802/opt.1250w.png
# Total verified matches: 35
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 91
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw41/produkte/1006150_41-2023_Curry45g-01._ON.png/_jcr_content/renditions/opt.1250w.png.res/1694785409250/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 92
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/alkoholfreie-getraenke/0106_40-2021_Smoothies250-Yellow_COMP.png/_jcr_content/renditions/opt.1250w.png.res/1631606100881/opt.1250w.png
# Failed to download image from URL: https://www.aldi-nord.de/content/dam/aldi/germany/produkte/alkoholfreie-getraenke/0106_40-2021_Smoothies250-Yellow_COMP.png/_jcr_content/renditions/opt.1250w.png.res/1631606100881/opt.1250w.png
# Error: Unable to download or process image
# Processing URL number: 93
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/tiefgekuehltes/4398_44-2021_GUTBIOGEMUESEPFANNE-Wintergenuss_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1635521536377/opt.1250w.png
# Failed to download image from URL: https://www.aldi-nord.de/content/dam/aldi/germany/produkte/tiefgekuehltes/4398_44-2021_GUTBIOGEMUESEPFANNE-Wintergenuss_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1635521536377/opt.1250w.png
# Error: Unable to download or process image
# Processing URL number: 94
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/vollsortiment_2020/6651_28-2020_BioRaeucherlachs-FS_ON.png/_jcr_content/renditions/opt.1250w.png.res/1596638633893/opt.1250w.png
# Total verified matches: 22
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 95
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/muesli-cornflakes-cerealien/1002325_48-2023_BasisMuesli-01_COMP.png/_jcr_content/renditions/opt.1250w.png.res/1701440890865/opt.1250w.png
# Total verified matches: 18
# Total RGB color matches out of 3 : 2
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 96
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/vollsortiment/1025143_01-2024_BioVollmilch-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1707296956632/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 97
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw01/produkte/1011691_01-2023_KokosnussMandelDrink-03_ON_Comp1.png/_jcr_content/renditions/opt.1250w.png.res/1671530350362/opt.1250w.png
# Total verified matches: 34
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 98
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2024/kw15/produkte/1023588_15-2024_GutBioQuinoaChiasamen-Chiasamen_ON.png/_jcr_content/renditions/opt.1250w.png.res/1710437522838/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 99
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2024/kw02/produkte/1026119_02-2024_BioMozzarella-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1702546173970/opt.1250w.png
# Total verified matches: 21
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 100
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/tiefgekuehltes/4501_38-2021_BioHaferflocken-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1632121309035/opt.1250w.png
# Total verified matches: 22
# Total RGB color matches out of 3 : 2
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 101
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2024/kw11/produkte/1029019_11-2024_BioVanilleExtrakt-GutBio_ON.png/_jcr_content/renditions/opt.1250w.png.res/1708455017456/opt.1250w.png
# Total verified matches: 30
# Total RGB color matches out of 3 : 2
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 102
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/suessigkeiten/1007290_36-2021_BIOREISWAFFELN-Ungesalzen_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1627391479362/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 103
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw17/produkte/4358_17-2023_BIOMUESLIKLASSIK-02_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1681470236783/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 104
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw03/produkte/4863_03-2023_BIOKNUSPERMUESLI-02_COMP2.png/_jcr_content/renditions/opt.1250w.png.res/1672936728574/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 105
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2024/kw02/produkte/1026199_02-2024_BergbauernWeidekaese-02_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1702546180742/opt.1250w.png
# Total verified matches: 2
# Total RGB color matches out of 3 : 1
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 106
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw41/produkte/2471_41-2023_BioBruehenSortiment-Klarebruehe_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1694783565813/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 107
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/fleisch/8642_24-2022_HaehnchenbrustFilet-Curry_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1670237654732/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 108
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw52/produkte/1029566_01-2024_BioCremaBohne-FS_ON.png/_jcr_content/renditions/opt.1250w.png.res/1702308264469/opt.1250w.png
# Total verified matches: 32
# Total RGB color matches out of 3 : 3
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 109
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/tiefgekuehltes/6882_44-2021_TKPASTAGERICHTE400G-Cannelloni4Kaese_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1631628610902/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 110
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/haushalt/7165_52-2021_Waeschehygienespueler-Sensitive_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1644585554239/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 111
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw36/produkte/5581_33-2023_GutBioObst-05_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1692372371082/opt.1250w.png
# Total verified matches: 7
# Total RGB color matches out of 3 : 2
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 112
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2022/kw23/produkte/4172_23-2022_CocaColaLightZero-Zero_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1652695306156/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 113
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw50/produkte/1028822_50-2023_ArielFluessig2L40WLColor-02_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1700474401349/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 114
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw38/produkte/6991_35-2023_BioWienerWuerstchen-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1693573642506/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 115
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/fleisch/8998_36-2023_HaehnchenBrustfTeilstueck-MM_ON.png/_jcr_content/renditions/opt.1250w.png.res/1690347387739/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 116
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw32/produkte/2997_32-2023_BioFruchtmus-ApfelErdbeer_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1689579550102/opt.1250w.png
# Total verified matches: 16
# Total RGB color matches out of 3 : 2
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 117
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/vollsortiment/7077_44-2023_Vollwaschmittel_ON.png/_jcr_content/renditions/opt.1250w.png.res/1701340567994/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 118
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/konserven/4325_41-2021_ERBSENSFMHREN425MLDOSE-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1637148582213/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 119
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/milchprodukte/6550_46-2021_JOGHURTAUFFRUCHT-Erdbeere_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1639482536296/opt.1250w.png
# Failed to download image from URL: https://www.aldi-nord.de/content/dam/aldi/germany/produkte/milchprodukte/6550_46-2021_JOGHURTAUFFRUCHT-Erdbeere_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1639482536296/opt.1250w.png
# Error: Unable to download or process image
# Processing URL number: 120
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/milchprodukte/1019000_48-2022_HFettarmeMilch-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1669969657429/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 121
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2022/kw28/produkte/1385_28-2022_GegarterSchweineb-02_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1656689375695/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 122
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw30/produkte/1009774_30-2023_DWTTaftHaarSprayLack-spray4_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1688470528071/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 123
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/salatdressing-oel-essig/0860_41-2021_BIOOLIVENL075L-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1632732697020/opt.1250w.png
# Failed to download image from URL: https://www.aldi-nord.de/content/dam/aldi/germany/produkte/salatdressing-oel-essig/0860_41-2021_BIOOLIVENL075L-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1632732697020/opt.1250w.png
# Error: Unable to download or process image
# Processing URL number: 124
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw49/produkte/4096_49-2023_PremiumCornichons-Honig_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1700044033913/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 125
# https://www.aldi-nord.de/content/dam/aldi/germany/angebote/2023/kw31/produkte/8053_40-2022_TKBIOBLACKTIGERGARNELEN180G-02_ON_Comp.png/_jcr_content/renditions/opt.1250w.png.res/1689673541758/opt.1250w.png
# Total verified matches: 15
# Total RGB color matches out of 3 : 2
# Detected: Bio     Actual: Bio
# ****************************************************************************************************
# Processing URL number: 126
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/milchprodukte/867_46-2021_Butterschmalz-01_ON.png/_jcr_content/renditions/opt.1250w.png.res/1634902856886/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
# Processing URL number: 127
# https://www.aldi-nord.de/content/dam/aldi/germany/produkte/vollsortiment/1028127_14-2024_Putenoberkeule-01_ON1.png/_jcr_content/renditions/opt.1250w.png.res/1711126467130/opt.1250w.png
# Total verified matches: 0
# Total RGB color matches out of 3 : 0
# Detected: Non-Bio     Actual: Non-Bio
# ****************************************************************************************************
